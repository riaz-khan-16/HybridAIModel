# %%
#Importing the Libraries
from sklearn.datasets import make_classification
from sklearn.datasets import make_classification
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.models import load_model
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd
df=pd.read_csv('3.csv')
df = df.dropna()
print(df)
df.isnull().sum()

# %%
df
# Out:
#         H2  CH4  C2H6  C2H4  C2H2   CO   CO2  BDV  IFT  Acid No  ...  \
# 0    123.0  199    96    89     4  631  2710   45   24     0.10  ...
# 1    126.0  189    91    86     6  620  2720   41   23     0.09  ...
# 2    125.0  188    92    83     6  680  2730   42   24     0.06  ...
# 3    430.0  299   114   123    20  750  4700   38   19     0.11  ...
# 4    440.0  244   115   124    21  752  4600   39   19     0.11  ...
# ..     ...  ...   ...   ...   ...  ...   ...  ...  ...      ...  ...
# 603    2.8  189   107    96    26  356  4856   43   20     0.09  ...
# 604    2.9  188   108    98    31  388  4863   44   20     0.09  ...
# 605    2.9  178   110    93    33  396  4236   45   19     0.10  ...
# 606    2.9  156   109    96    32  375  4852   41   20     0.10  ...
# 607    2.7  158   106    86     8  699  3311   42   20     0.10  ...
#
#      Conductivity Factor  Maintainance History  Age in Years  Load History  \
# ...

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

  
# draw lineplot
plt.figure(figsize=(4,4),dpi=1200)
sns.lineplot(x="H2", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="CH4", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="C2H6", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="C2H4", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="C2H2", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="CO", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="CO2", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="BDV", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="IFT", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(4,4),dpi=600)
sns.lineplot(x="Acid No", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Water Content", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Oil Color", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Dissipation Factor", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Turns Ratio Deviation", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Winding Resistance Deviation", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Power Factor", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Winding Temparature Rise", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Top Oil Temparature Rise", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Short Circuit Impedence", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Insulating Resistance", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Furan Content", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Polarization Index", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Exitation Current", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Frequency Domain Spectrocopy", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Sweep Frequency Response Analysis", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Conductivity Factor", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Maintainance History", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Age in Years", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Load History", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Operation Per Month", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="DGAF of LTC", y="Category-10", data=df)
plt.show()

# %%
plt.figure(figsize=(16,16))
sns.lineplot(x="Operation Per Month", y="Category-10", data=df)
plt.show()

# %%
X=df.drop(['Category','Category-10'],axis=1)
y=df['Category-10']

# %%
# importing packages
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df, hue ='Category')
# to show
plt.show()

# %%
sns.barplot(x='Category-10',y='H2',data=df)

# %%
df['Category-10'].value_counts()
# Out:
# 4     181
# 5     142
# 10     70
# 3      66
# 8      43
# 1      35
# 6      32
# 9      24
# 7      10
# 2       5
# Name: Category-10, dtype: int64

# %%
# split into train test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=1)
# scale data
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)

# %%
# AutoEncoder Model Preparation
n_inputs = X.shape[1]
# define encoder
input_data_shape= Input(shape=(n_inputs,))
# encoder level 1
encoder= Dense(n_inputs*2)(input_data_shape)
encoder = BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# encoder level 2
encoder= Dense(n_inputs)(encoder)
encoder= BatchNormalization()(encoder)
encoder= LeakyReLU()(encoder)
# bottleneck
n_bottleneck = round(float(n_inputs) / 2.0)
bottleneck = Dense(n_bottleneck)(encoder)
# define decoder, level 1
decoder = Dense(n_inputs)(bottleneck)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)
# decoder level 2
decoder = Dense(n_inputs*2)(decoder)
decoder = BatchNormalization()(decoder)
decoder = LeakyReLU()(decoder)

# %%
# output layer
output = Dense(n_inputs, activation='linear')(decoder)
# define autoencoder model
model = Model(inputs=input_data_shape, outputs=output)
# compile autoencoder model
model.compile(optimizer='adam', loss='mse')

# %%
import tensorflow
from tensorflow.keras.utils import plot_model
plot_model(model, 'autoencoder_no_compress.png', show_shapes=True)

# %%
model.summary()

# %%
history = model.fit(X_train, y_train, epochs=1000, batch_size=16, verbose=2, validation_data=(X_test,y_test))

# %%
# define an encoder model (without the decoder)
encoder = Model(inputs=input_data_shape, outputs=bottleneck)
# save the encoder to file
encoder.save('encoder.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
# plot loss
import matplotlib.pyplot as pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.legend()
pyplot.show()

# %%
# plot loss
import matplotlib.pyplot as pyplot
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
# plot loss
import matplotlib.pyplot as pyplot
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='test')
pyplot.legend()
pyplot.show()

# %%
#Building a Base Model to compare the performance after compressing the data using Encoder model.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from matplotlib.colors import ListedColormap
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
t = MinMaxScaler()
t.fit(X_train)
X_train = t.transform(X_train)
X_test = t.transform(X_test)

# %%
# define model
model=LogisticRegression()
# fit model on training set
model.fit(X_train, y_train)
# make prediction on test set
yhat = model.predict(X_test)
# calculate accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# 0.8032786885245902
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
data = X_train
# plotting the heatmap
hm = sns.heatmap(data = data)
  
# displaying the plotted heatmap
plt.show()

# %%
#Compressing the input data using Encoder Model and fitting it on the Logistic Regression model.
# load the model from file
encoder = load_model('encoder.h5')

# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model = LogisticRegression(max_iter=1000)
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ...
# 2/2 [==============================] - 0s 5ms/step
# 0.9672131147540983

# %%
data = X_train_encode
# plotting the heatmap
hm = sns.heatmap(data = data)
  
# displaying the plotted heatmap
plt.show()

# %%
#Compressing the input data using Encoder Model and fitting it on the Logistic Regression model.
# load the model from file
encoder = load_model('encoder.h5')

# encode the train data
X_train_encode = encoder.predict(X_train)
# encode the test data
X_test_encode = encoder.predict(X_test)
# define the model
model = LogisticRegression(max_iter=1000)
# fit the model on the training set
model.fit(X_train_encode, y_train)
# make predictions on the test set
yhat = model.predict(X_test_encode)
# calculate classification accuracy
acc = accuracy_score(y_test, yhat)
print(acc)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# ...
# 2/2 [==============================] - 0s 5ms/step
# 0.9672131147540983

# %%
model.predict(X_test_encode)
#Testing the model using X_test and storing the output in y_pred
y_pred = model.predict(X_test_encode)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, yhat)
# Creating a dataframe for a array-formatted Confusion matrix,so it will be easy for plotting.
cm_df = pd.DataFrame(cm,
                     index = ['0','1','2','3','4','5','6','7'], 
                     columns = ['0','1','2','3','4','5','6','7'])

# %%
#Plotting the confusion matrix
plt.figure(figsize=(4,4),dpi=1200)
sns.heatmap(cm_df, annot=True)
plt.title('Confusion Matrix')
plt.ylabel('Actual Values')
plt.xlabel('Predicted Values')
plt.show()
